# %%
list=[]

list2 = []


n = int(input("Enter number of elements : "))


for i in range(0, n):
	ele = int(input())
	list2.append(ele) 
print(list2)

for j in range(0,n):
    ele=int(input())
    list.append(ele)
print(list)
sum=0
for k in range(0,n):
    x=list[k]*list2[k]
    sum+=x
    
print(sum)
# Out:
# [1, 2, 3]
# [4, 5, 6]
# 32

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Iris.csv")

# %%
df[:100]
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0     1            5.1           3.5            1.4           0.2
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
import matplotlib.pyplot as plt

x_sepal = df.SepalLengthCm
y_petal = df.PetalLengthCm

color_sepal = 'blue'
color_petal = 'green'

plt.scatter(x_sepal, y_petal, c=[color_sepal]*len(x_sepal), edgecolors='red', label='Sepal and Petal')

plt.xlabel('Length_sepal')
plt.ylabel('Petal_length')
plt.title('Scatter Plot of Sepal and Petal Dimensions')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

x_sepal = df.SepalLengthCm
y_petal = df.PetalLengthCm



plt.scatter(x_sepal, y_petal, c=color_sepal , label='Sepal')
plt.scatter(x_sepal, y_petal, c=color_petal, label='Petal')

plt.xlabel('Length_sepal')
plt.ylabel('Petal_length')
plt.title('Scatter Plot of Sepal and Petal Dimensions')
plt.legend()
plt.show()

# %%
import seaborn as sns

sns.scatterplot(data=df,x='SepalLengthCm',y='PetalLengthCm',hue='Species')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\1BM21AI074_INN\22-11-2023.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/c%3A/1BM21AI074_INN/22-11-2023.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> import seaborn as sns
# ----> <a href='vscode-notebook-cell:/c%3A/1BM21AI074_INN/22-11-2023.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> sns.scatterplot(data=df,x='SepalLengthCm',y='PetalLengthCm',hue='Species')
#
# NameError: name 'df' is not defined
